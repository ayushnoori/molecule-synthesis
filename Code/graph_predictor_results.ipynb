# %%
from pathlib import Path

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
# Visual utilities
from multisynth.property_predictors.utils import graphing_utils
from multisynth.property_predictors.utils.printing import IPythonPrinter

# Models
from multisynth.property_predictors.plotting.chemprop_plotting import (
    plt_plot_chemprop_predictor_roc,
)

# %% [markdown]
# # Notebook Setup

# %% [markdown]
# ## Graphical Settings

# %%
graphing_utils.set_style() # Set up graph defaults
graphing_utils.set_color_pallete(None) # Set up color defaults

# %% [markdown]
# ## Export Settings

# %%
EXPORT_DIR_PATH = Path("../Data/graphics/")
SHOW_GRAPHICS = True
EXPORT_GRAPHICS = True

# %% [markdown]
# ## Utility Functions

# %%
def pyplot_plot(*args, **kwargs):
    if EXPORT_GRAPHICS:
        plt.savefig(*args, **kwargs)
    if SHOW_GRAPHICS:
        plt.show()

# %% [markdown]
# # Chemprop Predictors

# %% [markdown]
# ## Blood-Brain Barrier (BBB) Permeability

# %%
bbb_model_path = Path("../Data/property_predictors/chemprop_bbb_predictor/")

plt_plot_chemprop_predictor_roc(bbb_model_path, n_cross_validation_models=10)
pyplot_plot("chemprop_bbb_roc.png", dpi=300, bbox_inches="tight", transparent=True)

# %% [markdown]
# ## XXXXX Binding Affinity

# %%
# TODO
bbb_model_path = Path("../Data/property_predictors/chemprop_binding_predictor/")

plt_plot_chemprop_predictor_roc(bbb_model_path, n_cross_validation_models=10)
pyplot_plot("chemprop_bbb_roc.png", dpi=300, bbox_inches="tight", transparent=True)

# %% [markdown]
# # DeepPurpose Predictors

# %% [markdown]
# ## Absroption, Distribution, Metabolism, Excretion (ADME)

# %% [markdown]
# ## Toxicity
